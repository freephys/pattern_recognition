# %% [markdown]
# <b> Pattern Classification
#
# V. Mirjalili
# 04-04-2014 </b>
#
# <h1>Bayes Classification</h1>
#
# <h3>Description of input data </h3>
#
# Input data contains 2 features $\bar{x} =\left\{x_1, x_2\right\}$. Each sample belongs to one of the three classes: $\left\{w_1, w_2, w_3\right\}$.
# Overall, there are 1500 samples.
# First we will read the data into a numpy 2D array

# %%
import numpy as np
data = np.loadtxt('input_data.txt')
print(data.shape)
ntot = len(data)
# Out:
# (1500, 3)

# %% [markdown]
# <h4> Constructing Training and test sets</h4>
#
# Next, we create a training subset that contains 70% of all data (randomly selected),
# and assign the rest of data to a test set

# %%
#train_inx = (np.random.sample(100)*100).astype(int)
train_index = np.random.choice(np.arange(ntot), size=0.7*ntot, replace=False)
print(len(train_index))
# Out:
# 1050

# %%
X_train = data[train_index,0:]
#print(X_train[0:6])
X_test = data[list(set(np.arange(ntot)) - set(train_index)),:]
print(len(X_train), len(X_test))
# Out:
# (1050, 450)

# %% [markdown]
# <h4>Bayes Decision Rule Given Class Conditional Densities (PDFs)</h4>
#
# If we assume that the class conditional densities are as below:
#
# $ p(\underline{x} | w_1) \sim N([0,0]^t, 4I) $
#
# $ p(\bar{x} | w_2) \sim N([10,0]^t, 4I) $
#
# $ p(\bar{x} | w_3) \sim N([5,5]^t, 5I) $
#
# Having equal priors, $ P(w_1) = P(w_2) = P(w_3) $, and Bayes formula for posterior probability $ P(w_i | \bar{x}) = \frac{p(\bar{x}|w_i) P(w_i)}{P(\bar{x})} $, then we set up the discriminant functions $g_i = \ln P(w_i | \bar{x})$ in which equal priors and other constant terms can be omitted to reach:
#
# $ g_i = -\frac{1}{2}(x-\mu_i)^t \Sigma_i^{-1} (x-\mu_i) -\frac{1}{2} |\Sigma_i| \Longrightarrow -(x-\mu_i)^t \Sigma_i^{-1} (x-\mu_i) - |\Sigma_i|$
#
#
# Therefore, each pattern $x$ is classified to class $w_i$ whose discriminant function $g_i$ is maximum.
#
# Note that if we muliply it by $-1$, then we should consider minimum $g_i$ instead.

# %%
def mahalanobis_sqdist(x, mean, Sig_inv):
    '''
    Calculates the Mahalanobis Distance of pattern x
    to mean, given the inverse covariance matrix Sig_inv
    '''
    xdiff = x - mean
    return(np.dot(np.dot(xdiff, Sig_inv),xdiff))

#testing the function
x=X_train[1,0:2]
mahalanobis(x, np.array([0,0]), np.array([[1,2], [3,4]]))
# Out:
# 3.0079209999999996

# %%
import math
def g_discriminant(x, mean, Sig_inv):
    g = -mahalanobis_sqdist(x, mean, Sig_inv) + math.log(np.linalg.norm(Sig_inv))
    return g

#testing the function
print g_discriminant(x, np.array([0,0]), np.array([[1,2], [3,4]]))
# Out:
# -1.30732230917

# %% [markdown]
# Next, we apply 3 dicriminant functions on each pattern $x$ in the test set, and assign $x$ to the class that maximizae $g_i(x)$:

# %%
def predict(X, m1,m2,m3, S1,S2,S3):
    g1 = np.apply_along_axis(g_discriminant, 1, X, m1, S1)
    g2 = np.apply_along_axis(g_discriminant, 1, X, m2, S2)
    g3 = np.apply_along_axis(g_discriminant, 1, X, m3, S3)
    print (g1)
    
predict(X_test[:,0:2], np.array([0,0]),np.array([0,0]),np.array([0,0]),  np.array([[1,2], [3,4]]),np.array([[1,2], [3,4]]),np.array([[1,2], [3,4]]))
# Out:
# [ -6.94631790e+00  -5.51854827e+00  -7.03725781e+01  -3.51040477e+00
#   -2.30618080e+00  -8.55129181e+00  -2.86805534e+01  -8.40751015e+01
#    1.17723834e+00  -2.83966428e+01  -1.84361984e+01  -3.98196118e+00
#   -9.06539445e+00  -1.37272707e+02  -1.16643389e+01  -1.52380312e+01
#    2.46082025e+00  -3.78049509e-01  -1.24878510e+02  -6.71833341e+00
#   -1.54672905e+01  -2.41729852e+01  -3.81901756e+01  -1.22979429e+01
#   -2.72515841e+01  -3.55899833e+01  -1.11285721e+02  -1.86657861e+02
#   -2.65643127e+00  -7.52194648e+01   2.72244413e+00   4.61344591e-01
#   -4.54317261e+01  -1.35242140e+01  -9.87145379e+01  -2.47389435e+00
#   -7.58163196e+01  -3.06057826e+00  -7.03554067e+00  -9.48535081e+00
#    2.11589174e+00  -5.62519971e+01  -2.54639979e+00   2.50805219e+00
#   -1.57590315e+01   1.74166457e+00  -2.11687587e+00   1.43230313e+00
#   -3.64754018e+01   7.78260474e+00  -4.05153022e+00  -8.68515577e+00
#   -1.50192863e+01  -8.55643131e+00  -2.84331473e+01  -1.03946582e+01
#    2.53577853e+00  -1.40335587e+00  -1.11557861e+01  -1.45883865e+02
#   -3.43465811e+01  -2.23923271e+00  -4.34552643e+00   5.15745027e+00
#   -1.05815373e+01  -2.93532324e+01  -2.62436637e+01  -2.61476106e+01
#   -2.61947849e+01  -8.98954190e+01   4.56737148e+00  -2.53087231e+00
#    1.99270559e+00  -7.50581648e+01  -1.59376778e+01  -3.59790016e+01
#    2.92359897e+00  -2.05170359e+01  -4.95830344e+01  -9.69999540e+01
#   -3.31285929e+01   5.69114837e+00   3.65248089e+00   1.74809354e+00
#   -7.92496111e+00  -2.51377845e+01  -1.42948353e+01   2.10661256e+00
#    4.10260051e-01  -4.99730388e+01  -1.07801143e+00  -1.60971404e+01
#   -2.37585459e-01  -8.72638632e+00  -1.40843523e+01  -1.06038799e+01
#   -1.39481504e+02  -3.67428267e+01   2.02648861e-01  -5.32205079e-01
#   -4.59662975e+01   1.96595951e+00  -7.26987751e+00  -4.13821611e+00
#   -3.63801257e+01  -2.01031980e+01   4.87179243e+00  -6.94511235e+00
#    9.14995625e+00   2.04758477e+00  -5.09929155e+00  -1.10660406e+01
#   -3.92978232e+01  -3.10212163e+00   2.53944063e+00  -3.01489020e+01
#   -6.99570711e+00  -1.45924253e+01  -1.70918352e+00   2.83385711e+00
#   -7.23323611e+00  -3.57680803e+01  -1.28613554e+01   9.30791774e+00
#   -5.57568733e+01  -1.68954736e+00  -4.08475497e+01  -7.92203280e+01
#   -5.04423402e+01   1.36288944e+00  -2.10995178e+01  -5.96044266e+01
#    3.32492864e+00  -6.31960268e+01  -6.30623351e+01  -4.81978307e+01
#   -2.23135497e+02  -1.17895517e+01  -3.52568576e+01  -2.77549111e+00
#    7.01397811e-01   1.59686423e+00  -1.22440007e+02   3.83427056e+00
#   -2.40780271e+00  -1.37694838e+02  -6.17819263e+00  -1.12179635e+01
#   -1.92953383e+01   4.32248081e+00  -5.52507724e+00   1.74024587e+00
#   -3.99495430e+01  -5.32333639e+01  -7.33688089e+00   9.73935692e+00
#    4.62297891e-01   3.96285299e+00  -5.50318675e+01  -1.30700687e+02
#   -3.60163299e+01  -5.15462754e+01  -2.90388880e+02  -7.82081363e+01
#    3.08089221e+01  -4.00959867e+02  -1.71962639e+02  -1.33640377e+02
#   -3.30385644e+02  -5.39857749e+01  -3.24078690e+02  -5.90087393e+01
#   -1.14833647e+02  -2.60675832e+02  -1.73123224e+02   1.47244757e+00
#   -4.91063377e+01  -3.80933482e+02   2.88883084e+01  -5.85297957e+01
#   -3.23961376e+02  -1.54861852e+02  -2.74402029e+02  -2.60339750e+02
#   -3.14331668e+01  -1.18700690e+02  -2.23552730e+01  -2.00761584e+02
#    4.33866574e+01  -1.87509482e+02  -1.75234721e+02  -4.06519784e+01
#    1.04337623e+00  -1.77150122e+02  -2.06175227e+02  -1.12869718e+02
#   -4.68990476e+01  -2.52309067e+00  -1.21860765e+02   3.00989528e+00
#   -1.50647846e+02   8.53269481e-01   3.08634096e+01  -4.86879796e+02
#    2.03266262e+00  -4.53273852e+02  -1.42277895e+02  -9.76113892e+01
#   -9.11712462e+01  -4.28956940e+02  -9.31529843e+01   3.46330992e+01
#   -2.25851755e+02   2.80607921e+01   1.29322111e+01  -9.43510350e+01
#   -1.95686242e+01  -1.31566521e+02  -2.11468652e+02  -1.29498031e+02
#   -1.12850240e+02  -2.41843844e+02  -5.01914290e+01  -1.63446972e+02
#   -4.32367260e+01  -1.72518439e+01  -1.53618515e+01   1.39833552e+01
#   -1.67904720e+02  -2.53867328e+02  -2.35040927e+02  -4.43433429e+02
#   -1.35821845e+02  -5.56689401e+01  -3.87859771e+02   4.46845683e+01
#   -1.29169538e+02  -2.92562789e+02  -4.48661224e+02  -8.35504492e+01
#   -1.78762625e+01  -2.79679925e+02  -1.33905979e+02  -1.79013175e+02
#   -8.81121541e+01  -4.37375461e+02   2.68857212e+01  -3.26122453e+02
#   -2.01621540e+01  -1.05018975e+02  -4.86702183e+01  -5.30756918e+01
#   -4.08672386e+01  -2.41127421e+02  -1.71297867e+02  -1.77621211e+02
#    2.34807607e+01  -2.64435363e+02   1.03046989e+02   2.25192245e+01
#   -6.22821348e+01  -7.03531779e+01  -2.99372718e+02  -1.84471526e+01
#   -8.59961493e+01  -1.62066815e+02  -1.13762759e+02   2.24403188e+01
#   -3.51534965e+02  -5.08308882e+01  -2.19295581e+02  -2.46174471e+02
#   -2.04820989e+02  -1.78392469e+02   3.09798301e+01  -1.17814078e+02
#    1.85498038e+01  -2.45741547e+02  -9.13409011e+00  -3.35967872e+02
#    3.62499231e+01  -1.37364766e+02  -1.52408262e+02  -2.32332006e+02
#   -1.27836328e+02   1.28506205e+00  -6.76197609e+01  -1.16307568e+02
#   -8.91542555e+01  -2.65279355e+01  -4.45809566e+02   4.05948835e+01
#   -3.18827354e+01   5.02421329e+01  -4.72178400e+02  -1.11586353e+02
#   -1.58151892e+02  -1.65549701e+02  -3.58421760e+02  -2.49688906e+02
#   -4.44320945e+02  -1.79223171e+02  -1.68317568e+02  -5.84054733e+02
#   -1.67017240e+02  -2.30610320e+02  -1.43010620e+02  -2.85782649e+02
#   -3.28833013e+02  -1.88904743e+02  -5.08909833e+02  -4.41872938e+02
#   -1.55043557e+02  -1.03898275e+03  -6.16154136e+01  -2.99518671e+02
#   -4.99289581e+02  -3.29669037e+02  -5.74209367e+00  -3.15816773e+02
#   -3.28309420e+02  -2.65244505e+02  -4.93473465e+01  -9.15667738e+01
#   -2.66167795e+02  -2.60807418e+02  -5.60248737e+01  -9.89004018e+01
#   -2.11171330e+02  -3.12791649e+02  -1.78128608e+02  -1.91501712e+02
#   -2.07564929e+02  -2.70808548e+02  -7.53834701e+01  -1.51608083e+02
#   -6.26075115e+01  -2.12815625e+02  -5.18112180e+02  -3.15338789e+02
#   -1.67862659e+02  -3.74540979e+02  -3.46198189e+02  -3.80609634e+02
#   -2.59644064e+02  -2.78707703e+02  -2.29099058e+01  -4.45755549e+02
#   -6.23231976e+01  -2.99360506e+02  -6.16430267e+01  -3.32321746e+02
#   -3.48163313e+02  -6.36436486e+01  -2.21857665e+02  -2.01103378e+02
#   -5.63847473e+01  -2.07240423e+02  -2.83880888e+02  -1.07030040e+02
#   -4.36896775e+02  -2.50457846e+02  -5.79868671e+02  -1.64244992e+02
#   -4.13479310e+02  -3.11813537e+02  -1.78988604e+02  -7.91827351e+01
#   -4.28747742e+02  -4.04426162e+02  -2.50914752e+02  -3.13126688e+02
#   -9.15928494e+01  -1.34324554e+02  -2.39890279e+02  -3.72902695e+02
#   -1.35558168e+02  -1.30259559e+02  -1.63258613e+02  -2.80508667e+02
#   -6.20863310e+02  -2.36866910e+02  -6.29732398e+02  -2.04491483e+02
#   -6.44085848e+02  -3.07825118e+02  -3.83708272e+02  -6.42450985e+01
#   -1.62250762e+02  -1.37784920e+02  -2.14293616e+02  -4.21503008e+02
#   -1.49213110e+02  -2.86105296e+02  -4.78683499e+02  -3.44055807e+02
#   -2.92333452e+02  -2.54240991e+02  -2.67590636e+02  -4.47194821e+02
#   -1.58108284e+02  -6.25078219e+01  -1.48310220e+02  -5.45947357e+02
#   -2.27477491e+02  -3.53281280e+02  -3.38447888e+02  -1.22285458e+02
#   -2.51389004e+02  -1.86280537e+02  -1.37322730e+02  -4.14466427e+02
#   -9.77739086e+01  -1.65446259e+02  -1.82186128e+02  -1.80998800e+02
#   -6.87924174e+01  -5.80384778e+02  -3.17784122e+02  -3.94901422e+02
#   -1.33308303e+02  -3.32602384e+02  -6.88524331e+02  -3.54258500e+02
#   -2.81050811e+01  -4.12613234e+02  -2.45459938e+02  -3.77285186e+01
#   -8.41669389e+01  -4.59459251e+02  -2.13933989e+02  -5.86106790e+02
#   -4.25731283e+02  -3.26082877e+02  -3.53460351e+02  -5.22974788e+02
#   -4.62619000e+02  -1.69982708e+02  -1.81284614e+02  -4.02253461e+02
#   -2.31027907e+02  -1.74274998e+02  -6.20784379e+02  -5.28815212e+02
#   -1.48444270e+02  -3.57764121e+02  -1.04482899e+02  -5.76867443e+02
#   -2.95899888e+02  -4.47425113e+02]
